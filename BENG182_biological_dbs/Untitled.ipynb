# %%
from statistics import mean
P1_lengths = []
P2_lengths = []
p500 = []
p250 = []
p100 = []
with open("P1_lengths.txt", 'r') as f:
    for line in f:
        P1_lengths.append(int(line.strip()))
with open("P2_lengths.txt", 'r') as f:
    for line in f:
        P2_lengths.append(int(line.strip()))
with open("P1_lengths500.txt", 'r') as f:
    for line in f:
        p500.append(int(line.strip()))
with open("P1_lengths250.txt", 'r') as f:
    for line in f:
        p250.append(int(line.strip()))
with open("P1_lengths100.txt", 'r') as f:
    for line in f:
        p100.append(int(line.strip()))
print(mean(P1_lengths))
print(mean(p500))
print(mean(p250))
print(mean(p100))
# Out:
# 1802.7915831663327
# 854.8787878787879
# 441.62626262626264
# 174.07070707070707

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
fig2 = plt.figure()
fig3 = plt.figure()
ax1 = fig.add_subplot(111)
ax2 = fig2.add_subplot(111)
ax3 = fig3.add_subplot(111)
ax1.hist(P1_lengths,bins=10)
ax2.hist(P2_lengths, bins=10)
ax3.hist(P2_lengths, range=(0,100))
ax1.set_xlabel("Alignment Size (bases)")
ax2.set_xlabel("Alignment Size (bases)")
ax3.set_xlabel("Alignment Size (bases) [zoomed in at lower values]")
ax1.set_ylabel("Num of alignments w/ Indel = 0")
ax2.set_ylabel("Num of alignments w/ Indel = -20")
ax3.set_ylabel("Num of alignments w/ Indel = -20")
# Out:
# Text(0, 0.5, 'Num of alignments w/ Indel = -20')

# %%
import matplotlib.pyplot as plt
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.hist(p500)
ax1.set_xlabel("Alignment Size (bases) [n=500]")
ax1.set_ylabel("Num of alignments w/ Indel = 0")
# Out:
# Text(0, 0.5, 'Num of alignments w/ Indel = 0')

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.hist(p250)
ax2.set_xlabel("Alignment Size (bases) [n=250]")
ax2.set_ylabel("Num of alignments w/ Indel = 0")
# Out:
# Text(0, 0.5, 'Num of alignments w/ Indel = 0')

# %%
fig3 = plt.figure()
ax3 = fig3.add_subplot(111)
ax3.hist(p100)
ax3.set_xlabel("Alignment Size (bases) [n=100]")
ax3.set_ylabel("Num of alignments w/ Indel = 0")
# Out:
# Text(0, 0.5, 'Num of alignments w/ Indel = 0')

# %%
from statistics import mean
lens_30_30 = []
lens_20_20 = []
lens_5_5 = []
lens_1_1 = []
lens_1_20 = []
lens_20_1 = []
with open("lens_-30_-30.txt", 'r') as f:
    for line in f:
        lens_30_30.append(int(line.strip()))
with open("lens_-20_-20.txt", 'r') as f:
    for line in f:
        lens_20_20.append(int(line.strip()))
with open("lens_-5_-5.txt", 'r') as f:
    for line in f:
        lens_5_5.append(int(line.strip()))
with open("lens_-1_-1.txt", 'r') as f:
    for line in f:
        lens_1_1.append(int(line.strip()))        
with open("lens_-1_-20.txt", 'r') as f:
    for line in f:
        lens_1_20.append(int(line.strip()))
with open("lens_-20_-1.txt", 'r') as f:
    for line in f:
        lens_20_1.append(int(line.strip()))

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(lens_30_30)
ax.set_xlabel("Alignment Size (bases) [n=1000]")
ax.set_ylabel("Num of alignments: Indel=30, Mismatch=30")
# Out:
# Text(0, 0.5, 'Num of alignments: Indel=30, Mismatch=30')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(lens_20_20)
ax.set_xlabel("Alignment Size (bases) [n=1000]")
ax.set_ylabel("Num of alignments: Indel=20, Mismatch=20")
# Out:
# Text(0, 0.5, 'Num of alignments: Indel=20, Mismatch=20')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(lens_5_5)
ax.set_xlabel("Alignment Size (bases) [n=1000]")
ax.set_ylabel("Num of alignments: Indel=5, Mismatch=5")
# Out:
# Text(0, 0.5, 'Num of alignments: Indel=5, Mismatch=5')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(lens_1_1)
ax.set_xlabel("Alignment Size (bases) [n=1000]")
ax.set_ylabel("Num of alignments: Indel=1, Mismatch=1")
# Out:
# Text(0, 0.5, 'Num of alignments: Indel=1, Mismatch=1')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(lens_1_20)
ax.set_xlabel("Alignment Size (bases) [n=1000]")
ax.set_ylabel("Num of alignments: Indel=20, Mismatch=1")
# Out:
# Text(0, 0.5, 'Num of alignments: Indel=20, Mismatch=1')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(lens_20_1)
ax.set_xlabel("Alignment Size (bases) [n=1000]")
ax.set_ylabel("Num of alignments: Indel=1, Mismatch=20")
# Out:
# Text(0, 0.5, 'Num of alignments: Indel=1, Mismatch=20')
